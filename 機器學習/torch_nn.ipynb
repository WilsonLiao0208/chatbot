# %% [markdown]
# ## 掛載 Google 雲端硬碟

# %%
import os

from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 資料預處理

# %% [markdown]
# 載入資料

# %%
import numpy as np
import pandas as pd

path = 'drive/MyDrive/Colab Notebooks'

x_train = None
y_train = None

x_test = None
y_test = None

print('Training data:')
print(' x:', x_train.shape)
print(' y:', y_train.shape)
print()

print('Test data:')
print(' x:', x_test.shape)
print(' y:', y_test.shape)

# %% [markdown]
# 資料正規化 (normalization)

# %%
train_mean = None
train_std = None

x_train = x_train
x_test = x_test

# %% [markdown]
# 資料可視化 (visualization)

# %%
import matplotlib.pyplot as plt

t0_train = x_train
t1_train = x_train

plt.scatter(t0_train[:, 0], t0_train[:, 1])
plt.scatter(t1_train[:, 0], t1_train[:, 1], color='r')
plt.show()

# %% [markdown]
# 轉換成 PyTorch 資料集格式

# %%
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader



train_dataloader = None
test_dataloader = None

# %% [markdown]
# ## 定義超參數 (hyper parameters)

# %% [markdown]
# 建立神經網路 (neural network, nn)

# %%
from torch import nn

class MultiLayerPerceptron:
    def __init__(self):
        pass
    
    
mlp = MultiLayerPerceptron()
print(mlp)

# %% [markdown]
# 建立損失函數 (loss function)

# %%
loss_fn = None

# %% [markdown]
# 建立優化器 (optimizer)

# %%
optimizer = None

# %% [markdown]
# ## 訓練

# %% [markdown]
# 建立訓練函數

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()

# %% [markdown]
# 建立測試函數

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()

# %% [markdown]
# 開始訓練

# %%
epochs = 1
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, mlp, loss_fn, optimizer)
    test(test_dataloader, mlp, loss_fn)
print("Done!")

# %% [markdown]
# ## 實際應用模型

# %% [markdown]
# ### 單筆資料測試

# %% [markdown]
# ### 多筆資料測試
# 建立資料多筆資料

# %% [markdown]
# 應用神經網路處理資料

# %% [markdown]
# 將結果可視化
