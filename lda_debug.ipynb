# %% [markdown]
# # 檢查 Notebook 執行環境
#
# 確認目前使用的 Python 內核、Jupyter Notebook / JupyterLab 或 VS Code Notebook 執行環境是否正確啟動。

# %%
# 匯入繪圖與資料處理套件
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

print("套件匯入成功")

# %%
# 設定 Matplotlib inline
# %matplotlib inline
plt.rcParams['font.sans-serif'] = ['SimHei']  # 設定中文字體
plt.rcParams['axes.unicode_minus'] = False    # 解決負號顯示問題

print("Matplotlib inline 設定完成")

# %%
# 產生測試圖表
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(8, 6))
plt.plot(x, y)
plt.title('測試圖表：正弦波')
plt.xlabel('X 軸')
plt.ylabel('Y 軸')
plt.grid(True)
plt.show()

print("測試圖表生成完成")

# %% [markdown]
# # 驗證程式碼輸出與錯誤訊息
#
# 檢查執行結果面板與終端機輸出的錯誤訊息，找出可能導致圖表未顯示的原因。
#
# 如果上面的測試圖表沒有顯示，請檢查：
# - 是否有錯誤訊息？
# - 內核是否正常運行？
# - VS Code 設定中是否啟用了 Jupyter 支援？

# %% [markdown]
# # 排除常見問題
#
# 如果圖表仍然不顯示，請嘗試以下步驟：
#
# 1. **重新啟動內核**：在 Notebook 工具列中點擊「重新啟動」按鈕。
# 2. **更新套件**：確保 matplotlib 和相關套件是最新的。
#    ```python
#    !pip install --upgrade matplotlib
#    ```
# 3. **檢查後端設定**：如果使用 VS Code，確認 Jupyter 擴充功能已安裝並啟用。
# 4. **檢查 VS Code 設定**：在設定中搜尋 "jupyter"，確保相關選項正確。
# 5. **測試其他圖表庫**：如果 matplotlib 有問題，可以嘗試使用 plotly 或 seaborn。
#
# 如果問題持續，請提供具體的錯誤訊息以便進一步診斷。
